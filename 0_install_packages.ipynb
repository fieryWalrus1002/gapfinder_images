# %% [markdown]
# # Installing the packages
# The gapfinder package has a number of other python projects that it depends on. We need to install those before we can use the software. I'm assuming you are running this in vscode, vecause thats how I set it up. If not, I'm sure you can figure things out.
#
# Run the following code block. A task bar may pop up asking which python environment you want to use. If there is an option for "venv", selected that. Then run the following code block. It may take up to two minutes.
#
# If it also tells you that vscode needs to install vscode extensions. Do it!

# %%
# !python.exe -m pip install --upgrade pip
# !python.exe -m pip install -r requirements.txt
# !python.exe -m pip install -e .
# Out:
# Requirement already satisfied: pip in .\venv\lib\site-packages (24.3.1)
# Requirement already satisfied: matplotlib>=3.0.0 in .\venv\lib\site-packages (from -r requirements.txt (line 1)) (3.9.2)
# Requirement already satisfied: numpy>=2.0.0 in .\venv\lib\site-packages (from -r requirements.txt (line 2)) (2.1.3)
# Requirement already satisfied: opencv-python>=4.0.0.0 in .\venv\lib\site-packages (from -r requirements.txt (line 3)) (4.10.0.84)
# Requirement already satisfied: pandas>=2.0.0 in .\venv\lib\site-packages (from -r requirements.txt (line 4)) (2.2.3)
# Requirement already satisfied: pillow>=10.0.0 in .\venv\lib\site-packages (from -r requirements.txt (line 5)) (11.0.0)
# Requirement already satisfied: pytesseract>=0.3.13 in .\venv\lib\site-packages (from -r requirements.txt (line 6)) (0.3.13)
# Requirement already satisfied: PyYAML>=6.0.0 in .\venv\lib\site-packages (from -r requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: scipy>=1.0.0 in .\venv\lib\site-packages (from -r requirements.txt (line 8)) (1.14.1)
# Requirement already satisfied: seaborn>=0.11.0 in .\venv\lib\site-packages (from -r requirements.txt (line 9)) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in .\venv\lib\site-packages (from matplotlib>=3.0.0->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in .\venv\lib\site-packages (from matplotlib>=3.0.0->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\venv\lib\site-packages (from matplotlib>=3.0.0->-r requirements.txt (line 1)) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\venv\lib\site-packages (from matplotlib>=3.0.0->-r requirements.txt (line 1)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in .\venv\lib\site-packages (from matplotlib>=3.0.0->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in .\venv\lib\site-packages (from matplotlib>=3.0.0->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in .\venv\lib\site-packages (from matplotlib>=3.0.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\venv\lib\site-packages (from pandas>=2.0.0->-r requirements.txt (line 4)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in .\venv\lib\site-packages (from pandas>=2.0.0->-r requirements.txt (line 4)) (2024.2)
# Requirement already satisfied: six>=1.5 in .\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->-r requirements.txt (line 1)) (1.16.0)
# Obtaining file:///D:/repos/gapfinder_images
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pandas in .\venv\lib\site-packages (from gapfinder==0.1) (2.2.3)
# Requirement already satisfied: scipy in .\venv\lib\site-packages (from gapfinder==0.1) (1.14.1)
# Requirement already satisfied: numpy in .\venv\lib\site-packages (from gapfinder==0.1) (2.1.3)
# Requirement already satisfied: matplotlib in .\venv\lib\site-packages (from gapfinder==0.1) (3.9.2)
# Requirement already satisfied: seaborn in .\venv\lib\site-packages (from gapfinder==0.1) (0.13.2)
# Requirement already satisfied: opencv-python in .\venv\lib\site-packages (from gapfinder==0.1) (4.10.0.84)
# Requirement already satisfied: pillow in .\venv\lib\site-packages (from gapfinder==0.1) (11.0.0)
# Requirement already satisfied: pytesseract in .\venv\lib\site-packages (from gapfinder==0.1) (0.3.13)
# Requirement already satisfied: jupyter in .\venv\lib\site-packages (from gapfinder==0.1) (1.1.1)
# Requirement already satisfied: notebook in .\venv\lib\site-packages (from jupyter->gapfinder==0.1) (7.2.2)
# Requirement already satisfied: jupyter-console in .\venv\lib\site-packages (from jupyter->gapfinder==0.1) (6.6.3)
# Requirement already satisfied: nbconvert in .\venv\lib\site-packages (from jupyter->gapfinder==0.1) (7.16.4)
# Requirement already satisfied: ipykernel in .\venv\lib\site-packages (from jupyter->gapfinder==0.1) (6.29.5)
# Requirement already satisfied: ipywidgets in .\venv\lib\site-packages (from jupyter->gapfinder==0.1) (8.1.5)
# Requirement already satisfied: jupyterlab in .\venv\lib\site-packages (from jupyter->gapfinder==0.1) (4.2.5)
# Requirement already satisfied: contourpy>=1.0.1 in .\venv\lib\site-packages (from matplotlib->gapfinder==0.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in .\venv\lib\site-packages (from matplotlib->gapfinder==0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\venv\lib\site-packages (from matplotlib->gapfinder==0.1) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\venv\lib\site-packages (from matplotlib->gapfinder==0.1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in .\venv\lib\site-packages (from matplotlib->gapfinder==0.1) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in .\venv\lib\site-packages (from matplotlib->gapfinder==0.1) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in .\venv\lib\site-packages (from matplotlib->gapfinder==0.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\venv\lib\site-packages (from pandas->gapfinder==0.1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in .\venv\lib\site-packages (from pandas->gapfinder==0.1) (2024.2)
# Requirement already satisfied: six>=1.5 in .\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->gapfinder==0.1) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in .\venv\lib\site-packages (from ipykernel->jupyter->gapfinder==0.1) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in .\venv\lib\site-packages (from ipykernel->jupyter->gapfinder==0.1) (1.8.8)
# Requirement already satisfied: ipython>=7.23.1 in .\venv\lib\site-packages (from ipykernel->jupyter->gapfinder==0.1) (8.29.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in .\venv\lib\site-packages (from ipykernel->jupyter->gapfinder==0.1) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in .\venv\lib\site-packages (from ipykernel->jupyter->gapfinder==0.1) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in .\venv\lib\site-packages (from ipykernel->jupyter->gapfinder==0.1) (0.1.7)
# Requirement already satisfied: nest-asyncio in .\venv\lib\site-packages (from ipykernel->jupyter->gapfinder==0.1) (1.6.0)
# Requirement already satisfied: psutil in .\venv\lib\site-packages (from ipykernel->jupyter->gapfinder==0.1) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in .\venv\lib\site-packages (from ipykernel->jupyter->gapfinder==0.1) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in .\venv\lib\site-packages (from ipykernel->jupyter->gapfinder==0.1) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in .\venv\lib\site-packages (from ipykernel->jupyter->gapfinder==0.1) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in .\venv\lib\site-packages (from ipywidgets->jupyter->gapfinder==0.1) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in .\venv\lib\site-packages (from ipywidgets->jupyter->gapfinder==0.1) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in .\venv\lib\site-packages (from jupyter-console->jupyter->gapfinder==0.1) (3.0.48)
# Requirement already satisfied: pygments in .\venv\lib\site-packages (from jupyter-console->jupyter->gapfinder==0.1) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in .\venv\lib\site-packages (from jupyterlab->jupyter->gapfinder==0.1) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in .\venv\lib\site-packages (from jupyterlab->jupyter->gapfinder==0.1) (0.27.2)
# Requirement already satisfied: jinja2>=3.0.3 in .\venv\lib\site-packages (from jupyterlab->jupyter->gapfinder==0.1) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in .\venv\lib\site-packages (from jupyterlab->jupyter->gapfinder==0.1) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in .\venv\lib\site-packages (from jupyterlab->jupyter->gapfinder==0.1) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in .\venv\lib\site-packages (from jupyterlab->jupyter->gapfinder==0.1) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in .\venv\lib\site-packages (from jupyterlab->jupyter->gapfinder==0.1) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in .\venv\lib\site-packages (from jupyterlab->jupyter->gapfinder==0.1) (75.4.0)
# Requirement already satisfied: beautifulsoup4 in .\venv\lib\site-packages (from nbconvert->jupyter->gapfinder==0.1) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in .\venv\lib\site-packages (from nbconvert->jupyter->gapfinder==0.1) (6.2.0)
# Requirement already satisfied: defusedxml in .\venv\lib\site-packages (from nbconvert->jupyter->gapfinder==0.1) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in .\venv\lib\site-packages (from nbconvert->jupyter->gapfinder==0.1) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in .\venv\lib\site-packages (from nbconvert->jupyter->gapfinder==0.1) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in .\venv\lib\site-packages (from nbconvert->jupyter->gapfinder==0.1) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in .\venv\lib\site-packages (from nbconvert->jupyter->gapfinder==0.1) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in .\venv\lib\site-packages (from nbconvert->jupyter->gapfinder==0.1) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in .\venv\lib\site-packages (from nbconvert->jupyter->gapfinder==0.1) (1.5.1)
# Requirement already satisfied: tinycss2 in .\venv\lib\site-packages (from nbconvert->jupyter->gapfinder==0.1) (1.4.0)
# Requirement already satisfied: webencodings in .\venv\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->gapfinder==0.1) (0.5.1)
# Requirement already satisfied: anyio in .\venv\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->gapfinder==0.1) (4.6.2.post1)
# Requirement already satisfied: certifi in .\venv\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->gapfinder==0.1) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in .\venv\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->gapfinder==0.1) (1.0.6)
# Requirement already satisfied: idna in .\venv\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->gapfinder==0.1) (3.10)
# Requirement already satisfied: sniffio in .\venv\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->gapfinder==0.1) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in .\venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->gapfinder==0.1) (0.14.0)
# Requirement already satisfied: decorator in .\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->gapfinder==0.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in .\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->gapfinder==0.1) (0.19.2)
# Requirement already satisfied: stack-data in .\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->gapfinder==0.1) (0.6.3)
# Requirement already satisfied: colorama in .\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->gapfinder==0.1) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in .\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->gapfinder==0.1) (4.3.6)
# Requirement already satisfied: pywin32>=300 in .\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->gapfinder==0.1) (308)
# Requirement already satisfied: argon2-cffi>=21.1 in .\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in .\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in .\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in .\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in .\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in .\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (2.0.14)
# Requirement already satisfied: send2trash>=1.8.2 in .\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in .\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in .\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (1.8.0)
# Requirement already satisfied: babel>=2.10 in .\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->gapfinder==0.1) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in .\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->gapfinder==0.1) (0.9.28)
# Requirement already satisfied: jsonschema>=4.18.0 in .\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->gapfinder==0.1) (4.23.0)
# Requirement already satisfied: requests>=2.31 in .\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->gapfinder==0.1) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in .\venv\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter->gapfinder==0.1) (2.20.0)
# Requirement already satisfied: wcwidth in .\venv\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->gapfinder==0.1) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in .\venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->gapfinder==0.1) (2.6)
# Requirement already satisfied: argon2-cffi-bindings in .\venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in .\venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->gapfinder==0.1) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in .\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->gapfinder==0.1) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->gapfinder==0.1) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in .\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->gapfinder==0.1) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in .\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->gapfinder==0.1) (0.21.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in .\venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in .\venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (6.0.2)
# Requirement already satisfied: rfc3339-validator in .\venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in .\venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->gapfinder==0.1) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->gapfinder==0.1) (2.2.3)
# Requirement already satisfied: executing>=1.2.0 in .\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->gapfinder==0.1) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in .\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->gapfinder==0.1) (2.4.1)
# Requirement already satisfied: pure-eval in .\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->gapfinder==0.1) (0.2.3)
# Requirement already satisfied: fqdn in .\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (1.5.1)
# Requirement already satisfied: isoduration in .\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in .\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (3.0.0)
# Requirement already satisfied: uri-template in .\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in .\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in .\venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (1.17.1)
# Requirement already satisfied: pycparser in .\venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in .\venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in .\venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->gapfinder==0.1) (2.9.0.20241003)
# Building wheels for collected packages: gapfinder
#   Building editable for gapfinder (pyproject.toml): started
#   Building editable for gapfinder (pyproject.toml): finished with status 'done'
#   Created wheel for gapfinder: filename=gapfinder-0.1-0.editable-py3-none-any.whl size=2686 sha256=ce6f35bbddfc468e75a532d0bbf098671ec02a8cb5a6bed8d4414694a420b181
#   Stored in directory: C:\Users\magnus.wood\AppData\Local\Temp\pip-ephem-wheel-cache-jhla0rq8\wheels\a9\66\53\838dea88692a018d393b34a2398a5360e603b481d848ff4fd8
# Successfully built gapfinder
# Installing collected packages: gapfinder
#   Attempting uninstall: gapfinder
#     Found existing installation: gapfinder 0.1
#     Uninstalling gapfinder-0.1:
#       Successfully uninstalled gapfinder-0.1
# Successfully installed gapfinder-0.1

# %% [markdown]
# # Testing out the installation
#
# Now that we have these things installed, we need to make sure they work. Run the following code blocks, which will be tests of the code functionality. We want it to break here before we get too far!

# %%
# create the bare minimum directory structure
import os
import glob
import shutil

# Define directories
images_dir = "images"
output_dir = "output"
metadata_dir = "metadata"

# Create directories
os.makedirs(images_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)
os.makedirs(metadata_dir, exist_ok=True)

# test that they exist
assert os.path.exists(images_dir)
assert os.path.exists(output_dir)
assert os.path.exists(metadata_dir)

# %%
import os
import glob

# make sure that we have tif files somewhere in the images directory
# Like, say: images\tif_images\Wild Type - Dark Adapted\2022-1-10\Block 1\12 WT Dark 29k.tif
tif_files = glob.glob(os.path.join("images", "**", "*.tif"), recursive=True)

assert len(tif_files) > 0, "No tif files found in images directory, something is wrong"

# %% [markdown]
# # Tesseract
#
# This package depends on tesseract, an OCR tool to get text from an image. It uses the pytesseract library to interact with this system program. If the tesseract program is not installed on this computer, or if it has not been added to your system PATH variable, pytesseract will not be able to find it and use it.
#
# The error will look like this:
# TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.
#
# To fix this, you'll need to:
#    - download and build it from source, or
#    - install it from the packaged installer here: [UB-Mannheim Github page](https://github.com/UB-Mannheim/tesseract/wiki)
#
# To add a program to the PATH on a Windows machine, follow these steps:
#
# Find the Path to the Program: Locate the directory where the program's executable file is located. It should be "C:\Program Files\Tesseract-OCR" on the lab machine.
#
# Open Environment Variables:
#
# Press Win + X and select System.
# Click on Advanced system settings.
# In the System Properties window, click on the Environment Variables button.
#
# Edit the PATH Variable:
#
# In the Environment Variables window, find the Path variable in the System variables section and select it.
# Click on Edit.
#
# Add the New Path:
#
# In the Edit Environment Variable window, click on New.
# Add the path (eg "C:\Program Files\Tesseract-OCR") to the directory where the program's executable is located.
# Click OK to close all windows.
#
# Verify:
#
# Open a new Command Prompt window. The directory doesn't matter.
# Type in "tesseract --version" and hit enter.
# You should see a printout of the program version information.

# %%
# test out pytesseract
import pytesseract
import PIL

# if it still can't find it, you can directly specify it when you need to run pytesseract.
# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# open a test png file: gapfinder\images\ocrtest.png
test_image = PIL.Image.open("gapfinder/images/ocrtest.png")
text_ocr = pytesseract.image_to_string(test_image)

# strip any non-alphanumeric characters
text_ocr = ''.join(e for e in text_ocr if e.isalnum())

# test that the OCR worked
assert text_ocr == "Test", f"OCR did not work, got: {text_ocr}"
