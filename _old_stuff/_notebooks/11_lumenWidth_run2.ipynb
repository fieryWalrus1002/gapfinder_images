# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import glob
from scipy.signal import find_peaks
from scipy.signal import peak_widths

# %% [markdown]
# # Filter out the light-adapted strips

# %%
# output\trial_1\081624_rois_metadata_bignine.csv
metadata_all = pd.read_csv("./output/trial_1/081624_rois_metadata_bignine.csv")

metadata = metadata_all.copy()

# remove the light adapted strips. 
# 1. lower case the filename
metadata['filename'] = metadata['filename'].str.lower()
print(f"Before filtering out light-adapted images there are {len(metadata['filename'])} strips in the metadata.\n")

# 2. remove rows that don't contain 'dark'
metadata = metadata[metadata['filename'].str.contains('dark')]
print(f"After filtering, there are {len(metadata['filename'])} remaining.\n")

# get the strip numbers of the dark adapted strips
strip_filenames = metadata['strip_filename'].unique()

print(f"These are the remaining strips:")
for strip in metadata['strip_filename'].unique():
    print(f"\t{strip}")
    
# get the strips that were filtered out by comparing the strip_filenames in the metadata_all with the strip_numbers
filtered_out = metadata_all[~metadata_all['strip_filename'].isin(strip_filenames)]

print(f"These are the strips that were filtered out:")
for strip in filtered_out['strip_filename'].unique():
    print(f"\t{strip}")
    
    
# create a list of the isolated numbers from the strip filenames
strip_numbers = [int(strip.strip(".png").split('_')[-1]) for strip in strip_filenames]
print(f"\nThese are the strip numbers of the remaining strips: {strip_numbers}")
# Out:
# Before filtering out light-adapted images there are 9 strips in the metadata.
#
# After filtering, there are 8 remaining.
#
# These are the remaining strips:
# 	strip_106.png
# 	strip_134.png
# 	strip_135.png
# 	strip_161.png
# 	strip_176.png
# 	strip_187.png
# 	strip_229.png
# 	strip_232.png
# These are the strips that were filtered out:
# 	strip_101.png
#
# These are the strip numbers of the remaining strips: [106, 134, 135, 161, 176, 187, 229, 232]

# %% [markdown]
# # Filter the lumen df to only include the dark-adapted strips.

# %%
# load the lumen datafile with pd
lumen_data = pd.read_csv("./output/trial_1/csv/lumen_2.csv")

# print the length of the df 
print(f"Before filtering out the light-adapted strips, there are {len(lumen_data)} rows in the lumen data.\n")

# get the lumen data for the strips that were not filtered out
lumen_data = lumen_data[lumen_data['strip'].isin(strip_numbers)]

print(f"After filtering, there are {len(lumen_data)} remaining.\n")
# Out:
# Before filtering out the light-adapted strips, there are 20127 rows in the lumen data.
#
# After filtering, there are 18236 remaining.

# %% [markdown]
# # get the threshold metadata so we can reference it

# %%
th_metadata = pd.read_csv("./output/trial_1/threshold_metadata_2.csv", index_col=0)
th_metadata["process"] = th_metadata.index
print(th_metadata.head())
# Out:
#                     method  morph_key  equalize  blur  thresh  maxval  \
# 99_ostuOffset   ostuOffset  closeOpen      True  True      90     255
# 100_ostuOffset  ostuOffset  closeOpen      True  True      90     255
# 101_ostuOffset  ostuOffset  closeOpen      True  True      90     255
# 102_ostuOffset  ostuOffset  closeOpen      True  True      90     255
# 103_ostuOffset  ostuOffset  closeOpen      True  True      90     255
#
#                 blocksize  c  \
# 99_ostuOffset          25  2
# 100_ostuOffset         25  2
# 101_ostuOffset         25  2
# 102_ostuOffset         25  2
# 103_ostuOffset         25  2
#
#                                                        morph_args  offset  \
# 99_ostuOffset   {'name': 'closeOpen', 'closing_kernel': array(...   1.000
# 100_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.025
# 101_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.050
# 102_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.075
# 103_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.100
#
#                            key         process
# 99_ostuOffset    99_ostuOffset   99_ostuOffset
# 100_ostuOffset  100_ostuOffset  100_ostuOffset
# 101_ostuOffset  101_ostuOffset  101_ostuOffset
# 102_ostuOffset  102_ostuOffset  102_ostuOffset
# 103_ostuOffset  103_ostuOffset  103_ostuOffset

# %% [markdown]
# # calculate the mean width of the lumen, grouped by the process

# %%
# we need to get the mean width of the lumen for each image, but grouped by process. this is a groupby operation
mean_widths = lumen_data.groupby('process')['lumen_width_nm'].mean()

print(len(mean_widths))
print(mean_widths.head())

# sort the mean widths
mean_widths = mean_widths.sort_values()
expected_range = [4.5, 5]

# plot the mean widths. figsize the first number is the width, the second is the height
plt.figure(figsize=(10, 15))
mean_widths.plot(kind='barh')
plt.xlabel('Mean Lumen Width (nm)')
plt.ylabel('Process')
plt.title('Mean Lumen Width by Process')

# mark a dashed vertical line at the low and high end of the expected range
plt.axvline(expected_range[0], color='r', linestyle='--')
plt.axvline(expected_range[1], color='r', linestyle='--')

plt.show()
# Out:
# 331
# process
# 100_ostuOffset    5.906844
# 101_ostuOffset    5.750272
# 102_ostuOffset    5.563348
# 103_ostuOffset    5.433558
# 104_ostuOffset    5.266443
# Name: lumen_width_nm, dtype: float64

# %% [markdown]
# # Take a closer look at those in the range

# %%
# print the processes in mean_width that are within the range +/- 0.5 nm
# adjusted_range = [expected_range[0] - 0.5, expected_range[1] + 0.5]
adjusted_range = [expected_range[0], expected_range[1]]

adj_mean_widths = mean_widths[mean_widths.between(adjusted_range[0], adjusted_range[1])]
print(adj_mean_widths)
print(type(adj_mean_widths))
# Out:
# process
# 327_ostuOffset    4.513981
# 307_ostuOffset    4.513981
# 287_ostuOffset    4.513981
# 149_ostuOffset    4.521941
# 109_ostuOffset    4.521941
# 129_ostuOffset    4.521941
# 170_ostuOffset    4.544074
# 210_ostuOffset    4.544074
# 190_ostuOffset    4.544074
# 306_ostuOffset    4.639299
# 286_ostuOffset    4.639299
# 326_ostuOffset    4.639299
# 189_ostuOffset    4.644100
# 169_ostuOffset    4.644100
# 209_ostuOffset    4.644100
# 128_ostuOffset    4.667330
# 108_ostuOffset    4.667330
# 148_ostuOffset    4.667330
# 265_ostuOffset    4.672248
# 245_ostuOffset    4.672248
# 225_ostuOffset    4.672248
# 147_ostuOffset    4.709836
# 127_ostuOffset    4.709836
# 107_ostuOffset    4.709836
# 24_ostuOffset     4.727182
# 285_ostuOffset    4.823881
# 325_ostuOffset    4.823881
# 305_ostuOffset    4.823881
# 49_ostuOffset     4.843261
# 167_ostuOffset    4.845331
# 187_ostuOffset    4.845331
# 207_ostuOffset    4.845331
# 208_ostuOffset    4.853193
# 188_ostuOffset    4.853193
# 168_ostuOffset    4.853193
# 126_ostuOffset    4.871001
# 146_ostuOffset    4.871001
# 106_ostuOffset    4.871001
# 244_ostuOffset    4.876862
# 264_ostuOffset    4.876862
# 224_ostuOffset    4.876862
# 186_ostuOffset    4.956139
# 206_ostuOffset    4.956139
# 166_ostuOffset    4.956139
# Name: lumen_width_nm, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
# get the index for the processes that are within the range
adj_processes = adj_mean_widths.index
print(adj_processes)
# Out:
# Index(['327_ostuOffset', '307_ostuOffset', '287_ostuOffset', '149_ostuOffset',
#        '109_ostuOffset', '129_ostuOffset', '170_ostuOffset', '210_ostuOffset',
#        '190_ostuOffset', '306_ostuOffset', '286_ostuOffset', '326_ostuOffset',
#        '189_ostuOffset', '169_ostuOffset', '209_ostuOffset', '128_ostuOffset',
#        '108_ostuOffset', '148_ostuOffset', '265_ostuOffset', '245_ostuOffset',
#        '225_ostuOffset', '147_ostuOffset', '127_ostuOffset', '107_ostuOffset',
#        '24_ostuOffset', '285_ostuOffset', '325_ostuOffset', '305_ostuOffset',
#        '49_ostuOffset', '167_ostuOffset', '187_ostuOffset', '207_ostuOffset',
#        '208_ostuOffset', '188_ostuOffset', '168_ostuOffset', '126_ostuOffset',
#        '146_ostuOffset', '106_ostuOffset', '244_ostuOffset', '264_ostuOffset',
#        '224_ostuOffset', '186_ostuOffset', '206_ostuOffset', '166_ostuOffset'],
#       dtype='object', name='process')

# %%
# take the index of the th_metadata and create a column
th_metadata['in_range'] = th_metadata.index.isin(adj_processes)
print(len(th_metadata))

# filter the th_metadata to only include the processes that are in the range
df = th_metadata[th_metadata['in_range']].copy()
print(len(df))
# Out:
# 240
# 42

# %% [markdown]
# # The best results

# %%
# merge the series into the df, joining on the process column
df = df.merge(adj_mean_widths, left_on='process', right_index=True)
df
# Out:
#                     method  morph_key  equalize   blur  thresh  maxval  \
# 106_ostuOffset  ostuOffset  closeOpen      True   True      90     255
# 107_ostuOffset  ostuOffset  closeOpen      True   True      90     255
# 108_ostuOffset  ostuOffset  closeOpen      True   True      90     255
# 109_ostuOffset  ostuOffset  closeOpen      True   True      90     255
# 126_ostuOffset  ostuOffset  closeOpen      True   True     100     255
# 127_ostuOffset  ostuOffset  closeOpen      True   True     100     255
# 128_ostuOffset  ostuOffset  closeOpen      True   True     100     255
# 129_ostuOffset  ostuOffset  closeOpen      True   True     100     255
# 146_ostuOffset  ostuOffset  closeOpen      True   True     130     255
# 147_ostuOffset  ostuOffset  closeOpen      True   True     130     255
# 148_ostuOffset  ostuOffset  closeOpen      True   True     130     255
# 149_ostuOffset  ostuOffset  closeOpen      True   True     130     255
# 166_ostuOffset  ostuOffset  closeOpen      True  False      90     255
# 167_ostuOffset  ostuOffset  closeOpen      True  False      90     255
# 168_ostuOffset  ostuOffset  closeOpen      True  False      90     255
# 169_ostuOffset  ostuOffset  closeOpen      True  False      90     255
# 170_ostuOffset  ostuOffset  closeOpen      True  False      90     255
# 186_ostuOffset  ostuOffset  closeOpen      True  False     100     255
# 187_ostuOffset  ostuOffset  closeOpen      True  False     100     255
# 188_ostuOffset  ostuOffset  closeOpen      True  False     100     255
# 189_ostuOffset  ostuOffset  closeOpen      True  False     100     255
# 190_ostuOffset  ostuOffset  closeOpen      True  False     100     255
# 206_ostuOffset  ostuOffset  closeOpen      True  False     130     255
# 207_ostuOffset  ostuOffset  closeOpen      True  False     130     255
# 208_ostuOffset  ostuOffset  closeOpen      True  False     130     255
# 209_ostuOffset  ostuOffset  closeOpen      True  False     130     255
# 210_ostuOffset  ostuOffset  closeOpen      True  False     130     255
# 224_ostuOffset  ostuOffset  closeOpen     False   True      90     255
# 225_ostuOffset  ostuOffset  closeOpen     False   True      90     255
# 244_ostuOffset  ostuOffset  closeOpen     False   True     100     255
# 245_ostuOffset  ostuOffset  closeOpen     False   True     100     255
# 264_ostuOffset  ostuOffset  closeOpen     False   True     130     255
# 265_ostuOffset  ostuOffset  closeOpen     False   True     130     255
# 285_ostuOffset  ostuOffset  closeOpen     False  False      90     255
# 286_ostuOffset  ostuOffset  closeOpen     False  False      90     255
# 287_ostuOffset  ostuOffset  closeOpen     False  False      90     255
# 305_ostuOffset  ostuOffset  closeOpen     False  False     100     255
# 306_ostuOffset  ostuOffset  closeOpen     False  False     100     255
# 307_ostuOffset  ostuOffset  closeOpen     False  False     100     255
# 325_ostuOffset  ostuOffset  closeOpen     False  False     130     255
# 326_ostuOffset  ostuOffset  closeOpen     False  False     130     255
# 327_ostuOffset  ostuOffset  closeOpen     False  False     130     255
#
#                 blocksize  c  \
# 106_ostuOffset         25  2
# 107_ostuOffset         25  2
# 108_ostuOffset         25  2
# 109_ostuOffset         25  2
# 126_ostuOffset         25  2
# 127_ostuOffset         25  2
# 128_ostuOffset         25  2
# 129_ostuOffset         25  2
# 146_ostuOffset         25  2
# 147_ostuOffset         25  2
# 148_ostuOffset         25  2
# 149_ostuOffset         25  2
# 166_ostuOffset         25  2
# 167_ostuOffset         25  2
# 168_ostuOffset         25  2
# 169_ostuOffset         25  2
# 170_ostuOffset         25  2
# 186_ostuOffset         25  2
# 187_ostuOffset         25  2
# 188_ostuOffset         25  2
# 189_ostuOffset         25  2
# 190_ostuOffset         25  2
# 206_ostuOffset         25  2
# 207_ostuOffset         25  2
# 208_ostuOffset         25  2
# 209_ostuOffset         25  2
# 210_ostuOffset         25  2
# 224_ostuOffset         25  2
# 225_ostuOffset         25  2
# 244_ostuOffset         25  2
# 245_ostuOffset         25  2
# 264_ostuOffset         25  2
# 265_ostuOffset         25  2
# 285_ostuOffset         25  2
# 286_ostuOffset         25  2
# 287_ostuOffset         25  2
# 305_ostuOffset         25  2
# 306_ostuOffset         25  2
# 307_ostuOffset         25  2
# 325_ostuOffset         25  2
# 326_ostuOffset         25  2
# 327_ostuOffset         25  2
#
#                                                        morph_args  offset  \
# 106_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.175
# 107_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.200
# 108_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.225
# 109_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.250
# 126_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.175
# 127_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.200
# 128_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.225
# 129_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.250
# 146_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.175
# 147_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.200
# 148_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.225
# 149_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.250
# 166_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.175
# 167_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.200
# 168_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.225
# 169_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.250
# 170_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.275
# 186_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.175
# 187_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.200
# 188_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.225
# 189_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.250
# 190_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.275
# 206_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.175
# 207_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.200
# 208_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.225
# 209_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.250
# 210_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.275
# 224_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.125
# 225_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.150
# 244_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.125
# 245_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.150
# 264_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.125
# 265_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.150
# 285_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.150
# 286_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.175
# 287_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.200
# 305_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.150
# 306_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.175
# 307_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.200
# 325_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.150
# 326_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.175
# 327_ostuOffset  {'name': 'closeOpen', 'closing_kernel': array(...   1.200
#
#                            key         process  in_range  lumen_width_nm
# 106_ostuOffset  106_ostuOffset  106_ostuOffset      True        4.871001
# 107_ostuOffset  107_ostuOffset  107_ostuOffset      True        4.709836
# 108_ostuOffset  108_ostuOffset  108_ostuOffset      True        4.667330
# 109_ostuOffset  109_ostuOffset  109_ostuOffset      True        4.521941
# 126_ostuOffset  126_ostuOffset  126_ostuOffset      True        4.871001
# 127_ostuOffset  127_ostuOffset  127_ostuOffset      True        4.709836
# 128_ostuOffset  128_ostuOffset  128_ostuOffset      True        4.667330
# 129_ostuOffset  129_ostuOffset  129_ostuOffset      True        4.521941
# 146_ostuOffset  146_ostuOffset  146_ostuOffset      True        4.871001
# 147_ostuOffset  147_ostuOffset  147_ostuOffset      True        4.709836
# 148_ostuOffset  148_ostuOffset  148_ostuOffset      True        4.667330
# 149_ostuOffset  149_ostuOffset  149_ostuOffset      True        4.521941
# 166_ostuOffset  166_ostuOffset  166_ostuOffset      True        4.956139
# 167_ostuOffset  167_ostuOffset  167_ostuOffset      True        4.845331
# 168_ostuOffset  168_ostuOffset  168_ostuOffset      True        4.853193
# 169_ostuOffset  169_ostuOffset  169_ostuOffset      True        4.644100
# 170_ostuOffset  170_ostuOffset  170_ostuOffset      True        4.544074
# 186_ostuOffset  186_ostuOffset  186_ostuOffset      True        4.956139
# 187_ostuOffset  187_ostuOffset  187_ostuOffset      True        4.845331
# 188_ostuOffset  188_ostuOffset  188_ostuOffset      True        4.853193
# 189_ostuOffset  189_ostuOffset  189_ostuOffset      True        4.644100
# 190_ostuOffset  190_ostuOffset  190_ostuOffset      True        4.544074
# 206_ostuOffset  206_ostuOffset  206_ostuOffset      True        4.956139
# 207_ostuOffset  207_ostuOffset  207_ostuOffset      True        4.845331
# 208_ostuOffset  208_ostuOffset  208_ostuOffset      True        4.853193
# 209_ostuOffset  209_ostuOffset  209_ostuOffset      True        4.644100
# 210_ostuOffset  210_ostuOffset  210_ostuOffset      True        4.544074
# 224_ostuOffset  224_ostuOffset  224_ostuOffset      True        4.876862
# 225_ostuOffset  225_ostuOffset  225_ostuOffset      True        4.672248
# 244_ostuOffset  244_ostuOffset  244_ostuOffset      True        4.876862
# 245_ostuOffset  245_ostuOffset  245_ostuOffset      True        4.672248
# 264_ostuOffset  264_ostuOffset  264_ostuOffset      True        4.876862
# 265_ostuOffset  265_ostuOffset  265_ostuOffset      True        4.672248
# 285_ostuOffset  285_ostuOffset  285_ostuOffset      True        4.823881
# 286_ostuOffset  286_ostuOffset  286_ostuOffset      True        4.639299
# 287_ostuOffset  287_ostuOffset  287_ostuOffset      True        4.513981
# 305_ostuOffset  305_ostuOffset  305_ostuOffset      True        4.823881
# 306_ostuOffset  306_ostuOffset  306_ostuOffset      True        4.639299
# 307_ostuOffset  307_ostuOffset  307_ostuOffset      True        4.513981
# 325_ostuOffset  325_ostuOffset  325_ostuOffset      True        4.823881
# 326_ostuOffset  326_ostuOffset  326_ostuOffset      True        4.639299
# 327_ostuOffset  327_ostuOffset  327_ostuOffset      True        4.513981

# %%
import os
import shutil
import glob

# Isolate the data that has blurring and equalization, and has an offset within 1.2 and 1.17
df = df[(df['blur'] == True) & (df['equalize'] == True) & (df['offset'].between(1.17, 1.2))]

print(len(df))

# print out the process names in a list:
for process in df['process']:
    print(process)
# Out:
# 6
# 106_ostuOffset
# 107_ostuOffset
# 126_ostuOffset
# 127_ostuOffset
# 146_ostuOffset
# 147_ostuOffset

# %%
for process in df['process']:
    src = os.path.join("./output/trial_1/processed_images", process)
    dst = os.path.join("./output/trial_1/poi", process)
    os.makedirs(dst, exist_ok=True)
    print(f"Copying {src} to {dst}")
    shutil.copytree(src, dst, dirs_exist_ok=True)
    
    # Copy the masks as well
    masks_src = os.path.join("./output/trial_1/masks", process, "*.png")
    masks_dst = os.path.join(dst, "masks")
    os.makedirs(masks_dst, exist_ok=True)
    for mask in glob.glob(masks_src):
        shutil.copy2(mask, masks_dst)
# Out:
# Copying ./output/trial_1/processed_images\106_ostuOffset to ./output/trial_1/poi\106_ostuOffset
# Copying ./output/trial_1/processed_images\107_ostuOffset to ./output/trial_1/poi\107_ostuOffset
# Copying ./output/trial_1/processed_images\126_ostuOffset to ./output/trial_1/poi\126_ostuOffset
# Copying ./output/trial_1/processed_images\127_ostuOffset to ./output/trial_1/poi\127_ostuOffset
# Copying ./output/trial_1/processed_images\146_ostuOffset to ./output/trial_1/poi\146_ostuOffset
# Copying ./output/trial_1/processed_images\147_ostuOffset to ./output/trial_1/poi\147_ostuOffset

# %%
# for each process, print out the lumen width for each strip
for process in df['process']:
    print(f"Process {process}:")
    
    
    process_df = lumen_data[lumen_data['process'] == process]
    
    for strip in process_df['strip'].unique():
        print(f"Strip {strip}:")
        print(process_df[process_df['strip'] == strip]['lumen_width_nm'])
        
        # print out th mean lumen width for each strip
        print(f"Mean lumen width: {process_df[process_df['strip'] == strip]['lumen_width_nm'].mean()}")
        print("\n")
# Out:
# Process 106_ostuOffset:
# Strip 106:
# 344    5.324527
# 345    5.306677
# 346    5.287966
# 347    4.514025
# 348    4.420345
# 349    5.116701
# 350    4.510218
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.925779795062359
#
#
# Strip 134:
# 351    4.419924
# 352    4.493415
# 353    4.426456
# 354    3.667850
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.251911594058652
#
#
# Strip 135:
# 355    5.130271
# 356    4.691548
# 357    3.790473
# 358    3.823082
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.3588435270330645
#
#
# Strip 161:
# 359    4.439086
# 360    5.109364
# 361    4.685417
# 362    4.621059
# 363    3.558247
# 364    2.815083
# 365    4.513217
# 366    3.766026
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.1884373313989816
#
#
# Strip 176:
# 367    4.155844
# 368    4.649316
# 369    3.994361
# 370    5.057799
# 371    5.942235
# 372    5.113636
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.81886509146511
#
#
# Strip 187:
# 373    4.149449
# 374    6.060606
# 375    5.143152
# 376    6.132346
# 377    4.370629
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 5.171236591691136
#
#
# Strip 229:
# 378    4.942636
# 379    6.318829
# 380    4.753396
# 381    5.221787
# 382    3.871142
# 383    5.371062
# 384    3.613915
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.870395397470519
#
#
# Strip 232:
# 385    5.785124
# 386    5.935655
# 387    5.853521
# 388    6.868132
# 389    5.438312
# 390    4.301948
# 391    6.104312
# 392    5.324221
# 393    6.339914
# 394    6.005569
# 395    4.042208
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 5.636265135232073
#
#
# Process 107_ostuOffset:
# Strip 106:
# 401    5.127672
# 402    4.951527
# 403    5.215314
# 404    4.346843
# 405    4.337900
# 406    5.050068
# 407    4.263581
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.7561292629766205
#
#
# Strip 134:
# 408    4.393488
# 409    4.253098
# 410    4.370744
# 411    3.234399
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.062932420389866
#
#
# Strip 135:
# 412    5.052290
# 413    4.569180
# 414    3.790473
# 415    3.786149
# 416    7.656531
# 417    0.570776
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.237566596800692
#
#
# Strip 161:
# 418    4.067264
# 419    4.799107
# 420    4.648760
# 421    4.568182
# 422    3.524080
# 423    2.770226
# 424    4.020793
# 425    3.739316
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.0172161371304895
#
#
# Strip 176:
# 426    4.063216
# 427    4.545455
# 428    3.878066
# 429    4.990037
# 430    5.736804
# 431    4.958678
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.695375861496268
#
#
# Strip 187:
# 432    4.126155
# 433    5.888430
# 434    5.116096
# 435    5.643254
# 436    4.335017
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 5.021790202271484
#
#
# Strip 229:
# 437    4.919548
# 438    6.238717
# 439    4.598471
# 440    4.989853
# 441    3.650773
# 442    5.165396
# 443    3.456951
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.717101328091828
#
#
# Strip 232:
# 444    5.147652
# 445    5.912737
# 446    5.836039
# 447    6.629698
# 448    5.333141
# 449    4.222371
# 450    6.104312
# 451    5.272568
# 452    6.035354
# 453    5.883132
# 454    4.545455
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 5.53840529595258
#
#
# Process 126_ostuOffset:
# Strip 106:
# 1622    5.324527
# 1623    5.306677
# 1624    5.287966
# 1625    4.514025
# 1626    4.420345
# 1627    5.116701
# 1628    4.510218
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.925779795062359
#
#
# Strip 134:
# 1629    4.419924
# 1630    4.493415
# 1631    4.426456
# 1632    3.667850
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.251911594058652
#
#
# Strip 135:
# 1633    5.130271
# 1634    4.691548
# 1635    3.790473
# 1636    3.823082
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.3588435270330645
#
#
# Strip 161:
# 1637    4.439086
# 1638    5.109364
# 1639    4.685417
# 1640    4.621059
# 1641    3.558247
# 1642    2.815083
# 1643    4.513217
# 1644    3.766026
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.1884373313989816
#
#
# Strip 176:
# 1645    4.155844
# 1646    4.649316
# 1647    3.994361
# 1648    5.057799
# 1649    5.942235
# 1650    5.113636
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.81886509146511
#
#
# Strip 187:
# 1651    4.149449
# 1652    6.060606
# 1653    5.143152
# 1654    6.132346
# 1655    4.370629
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 5.171236591691136
#
#
# Strip 229:
# 1656    4.942636
# 1657    6.318829
# 1658    4.753396
# 1659    5.221787
# 1660    3.871142
# 1661    5.371062
# 1662    3.613915
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.870395397470519
#
#
# Strip 232:
# 1663    5.785124
# 1664    5.935655
# 1665    5.853521
# 1666    6.868132
# 1667    5.438312
# 1668    4.301948
# 1669    6.104312
# 1670    5.324221
# 1671    6.339914
# 1672    6.005569
# 1673    4.042208
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 5.636265135232073
#
#
# Process 127_ostuOffset:
# Strip 106:
# 1679    5.127672
# 1680    4.951527
# 1681    5.215314
# 1682    4.346843
# 1683    4.337900
# 1684    5.050068
# 1685    4.263581
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.7561292629766205
#
#
# Strip 134:
# 1686    4.393488
# 1687    4.253098
# 1688    4.370744
# 1689    3.234399
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.062932420389866
#
#
# Strip 135:
# 1690    5.052290
# 1691    4.569180
# 1692    3.790473
# 1693    3.786149
# 1694    7.656531
# 1695    0.570776
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.237566596800692
#
#
# Strip 161:
# 1696    4.067264
# 1697    4.799107
# 1698    4.648760
# 1699    4.568182
# 1700    3.524080
# 1701    2.770226
# 1702    4.020793
# 1703    3.739316
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.0172161371304895
#
#
# Strip 176:
# 1704    4.063216
# 1705    4.545455
# 1706    3.878066
# 1707    4.990037
# 1708    5.736804
# 1709    4.958678
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.695375861496268
#
#
# Strip 187:
# 1710    4.126155
# 1711    5.888430
# 1712    5.116096
# 1713    5.643254
# 1714    4.335017
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 5.021790202271484
#
#
# Strip 229:
# 1715    4.919548
# 1716    6.238717
# 1717    4.598471
# 1718    4.989853
# 1719    3.650773
# 1720    5.165396
# 1721    3.456951
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.717101328091828
#
#
# Strip 232:
# 1722    5.147652
# 1723    5.912737
# 1724    5.836039
# 1725    6.629698
# 1726    5.333141
# 1727    4.222371
# 1728    6.104312
# 1729    5.272568
# 1730    6.035354
# 1731    5.883132
# 1732    4.545455
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 5.53840529595258
#
#
# Process 146_ostuOffset:
# Strip 106:
# 2957    5.324527
# 2958    5.306677
# 2959    5.287966
# 2960    4.514025
# 2961    4.420345
# 2962    5.116701
# 2963    4.510218
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.925779795062359
#
#
# Strip 134:
# 2964    4.419924
# 2965    4.493415
# 2966    4.426456
# 2967    3.667850
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.251911594058652
#
#
# Strip 135:
# 2968    5.130271
# 2969    4.691548
# 2970    3.790473
# 2971    3.823082
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.3588435270330645
#
#
# Strip 161:
# 2972    4.439086
# 2973    5.109364
# 2974    4.685417
# 2975    4.621059
# 2976    3.558247
# 2977    2.815083
# 2978    4.513217
# 2979    3.766026
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.1884373313989816
#
#
# Strip 176:
# 2980    4.155844
# 2981    4.649316
# 2982    3.994361
# 2983    5.057799
# 2984    5.942235
# 2985    5.113636
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.81886509146511
#
#
# Strip 187:
# 2986    4.149449
# 2987    6.060606
# 2988    5.143152
# 2989    6.132346
# 2990    4.370629
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 5.171236591691136
#
#
# Strip 229:
# 2991    4.942636
# 2992    6.318829
# 2993    4.753396
# 2994    5.221787
# 2995    3.871142
# 2996    5.371062
# 2997    3.613915
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.870395397470519
#
#
# Strip 232:
# 2998    5.785124
# 2999    5.935655
# 3000    5.853521
# 3001    6.868132
# 3002    5.438312
# 3003    4.301948
# 3004    6.104312
# 3005    5.324221
# 3006    6.339914
# 3007    6.005569
# 3008    4.042208
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 5.636265135232073
#
#
# Process 147_ostuOffset:
# Strip 106:
# 3014    5.127672
# 3015    4.951527
# 3016    5.215314
# 3017    4.346843
# 3018    4.337900
# 3019    5.050068
# 3020    4.263581
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.7561292629766205
#
#
# Strip 134:
# 3021    4.393488
# 3022    4.253098
# 3023    4.370744
# 3024    3.234399
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.062932420389866
#
#
# Strip 135:
# 3025    5.052290
# 3026    4.569180
# 3027    3.790473
# 3028    3.786149
# 3029    7.656531
# 3030    0.570776
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.237566596800692
#
#
# Strip 161:
# 3031    4.067264
# 3032    4.799107
# 3033    4.648760
# 3034    4.568182
# 3035    3.524080
# 3036    2.770226
# 3037    4.020793
# 3038    3.739316
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.0172161371304895
#
#
# Strip 176:
# 3039    4.063216
# 3040    4.545455
# 3041    3.878066
# 3042    4.990037
# 3043    5.736804
# 3044    4.958678
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.695375861496268
#
#
# Strip 187:
# 3045    4.126155
# 3046    5.888430
# 3047    5.116096
# 3048    5.643254
# 3049    4.335017
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 5.021790202271484
#
#
# Strip 229:
# 3050    4.919548
# 3051    6.238717
# 3052    4.598471
# 3053    4.989853
# 3054    3.650773
# 3055    5.165396
# 3056    3.456951
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 4.717101328091828
#
#
# Strip 232:
# 3057    5.147652
# 3058    5.912737
# 3059    5.836039
# 3060    6.629698
# 3061    5.333141
# 3062    4.222371
# 3063    6.104312
# 3064    5.272568
# 3065    6.035354
# 3066    5.883132
# 3067    4.545455
# Name: lumen_width_nm, dtype: float64
# Mean lumen width: 5.53840529595258
